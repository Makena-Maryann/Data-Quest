# %% [markdown]
# ## EDA in Pandas

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Import the dataset
df = pd.read_csv("health-facilities-in-kenya.csv")
df
# Out:
#        Facility Code                                Facility Name  \
# 0              19224                       CDF Kiriari Dispensary
# 1              19310   St Jude's Huruma Community Health Services
# 2              14180                              10 Engineer VCT
# 3              17486                                 12 Engineers
# 4              18393                 3Kl Maternity & Nursing Home
# ...              ...                                          ...
# 10500          17220                                     Ziwa SDA
# 10501          15788                   Ziwa Sub-District Hospital
# 10502          11915                            Ziwani Dispensary
# 10503          16997                    Zombe Catholic Dispensary
# 10504          20313                         Zombe medical clinic
#
#           Province        County       District            Division  \
# 0          Eastern          Embu       Manyatta            Manyatta
# 1          Nairobi       Nairobi        Mathare              Huruma
# 2      Rift Valley      Laikipia  Laikipia East             Central
# 3          Central        Kiambu     Thika West                 NaN
# 4      Rift Valley       Kajiado  Kajiado North       Ongata Rongai
# ...            ...           ...            ...                 ...
# 10500  Rift Valley   Uasin Gishu   Eldoret West                 Soy
# 10501  Rift Valley   Uasin Gishu   Eldoret West                 Soy
# 10502        Coast  Taita Taveta         Taveta              Challa
# 10503      Eastern         Kitui         Mutitu  zombe/mwitika ward
# 10504      Eastern         Kitui         Mutitu  zombe/mwitika ward
#
#                         Type                                            Owner  \
# 0                 Dispensary                               Ministry of Health
# 1             Medical Clinic                   Private Practice - Unspecified
# 2                 Dispensary                                     Armed Forces
# 3                 Dispensary                               Ministry of Health
# 4               Nursing Home              Private Practice - Clinical Officer
# ...                      ...                                              ...
# 10500             Dispensary            Christian Health Association of Kenya
# 10501  Sub-District Hospital                               Ministry of Health
# 10502             Dispensary                 Private Enterprise (Institution)
# 10503             Dispensary  Kenya Episcopal Conference-Catholic Secretariat
# 10504         Medical Clinic              Private Practice - Clinical Officer
#
#       Location Sub Location  ...  IPD OPD OUTREACH  PMTCT  RAD/XRAY RHTC/RHDC  \
# 0       Ruguru       Ruguru  ...  NaN NaN      NaN    NaN       NaN       NaN
# 1       Huruma       Huruma  ...  NaN NaN      NaN    NaN       NaN       NaN
# 2      Nanyuki      Majengo  ...  NaN NaN      NaN    NaN       NaN       NaN
# 3          NaN          NaN  ...  NaN NaN      NaN    NaN       NaN       NaN
# 4       Gataka       Gataka  ...  NaN NaN      NaN    NaN       NaN       NaN
# ...        ...          ...  ...  ...  ..      ...    ...       ...       ...
# 10500     Ziwa      Sirikwa  ...  NaN NaN      NaN    NaN       NaN       NaN
# 10501  Sirikwa      Sirikwa  ...    Y NaN      NaN    NaN       NaN       NaN
# 10502   Challa       Ziwani  ...    Y NaN      NaN    NaN       NaN       NaN
# 10503    Zombe         Thua  ...  NaN NaN      NaN    NaN       NaN       NaN
# 10504    Zombe     Malalani  ...  NaN NaN      NaN    NaN       NaN       NaN
#
#       TB DIAG TB LABS TB TREAT YOUTH
# 0         NaN     NaN      NaN   NaN
# 1         NaN     NaN      NaN   NaN
# 2         NaN     NaN      NaN   NaN
# 3         NaN     NaN      NaN   NaN
# 4         NaN     NaN      NaN   NaN
# ...       ...     ...      ...   ...
# 10500     NaN     NaN      NaN   NaN
# 10501     NaN     NaN      NaN   NaN
# 10502     NaN     NaN      NaN   NaN
# 10503     NaN     NaN      NaN   NaN
# 10504     NaN     NaN      NaN   NaN
#
# [10505 rows x 50 columns]

# %% [markdown]
# We have 10505 rows in the dataset and 50 columns.

# %%
# Get info on our data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10505 entries, 0 to 10504
# Data columns (total 50 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Facility Code            10505 non-null  int64
#  1   Facility Name            10505 non-null  object
#  2   Province                 10505 non-null  object
#  3   County                   10505 non-null  object
#  4   District                 10505 non-null  object
#  5   Division                 10238 non-null  object
#  6   Type                     10505 non-null  object
#  7   Owner                    10505 non-null  object
#  8   Location                 10010 non-null  object
#  9   Sub Location             9613 non-null   object
#  10  Description of Location  5304 non-null   object
#  11  Constituency             10505 non-null  object
#  12  Nearest Town             9903 non-null   object
#  13  Beds                     10418 non-null  float64
#  14  Cots                     10428 non-null  float64
#  15  Official Landline        1367 non-null   object
#  16  Official Fax             540 non-null    object
#  17  Official Mobile          2915 non-null   object
#  18  Official Email           1857 non-null   object
#  19  Official Address         7047 non-null   object
#  20  Official Alternate No    952 non-null    float64
#  21  Town                     7838 non-null   object
#  22  Post Code                6680 non-null   object
#  23  In Charge                8365 non-null   object
#  24  Job Title of in Charge   7406 non-null   object
#  25  Open 24 Hours            10058 non-null  object
#  26  Open Weekends            10048 non-null  object
#  27  Operational Status       10505 non-null  object
#  28  ANC                      0 non-null      float64
#  29  ART                      921 non-null    object
#  30  BEOC                     0 non-null      float64
#  31  BLOOD                    0 non-null      float64
#  32  CAES SEC                 0 non-null      float64
#  33  CEOC                     0 non-null      float64
#  34  C-IMCI                   1177 non-null   object
#  35  EPI                      0 non-null      float64
#  36  FP                       4288 non-null   object
#  37  GROWM                    0 non-null      float64
#  38  HBC                      2798 non-null   object
#  39  HCT                      0 non-null      float64
#  40  IPD                      3943 non-null   object
#  41  OPD                      0 non-null      float64
#  42  OUTREACH                 0 non-null      float64
#  43  PMTCT                    0 non-null      float64
#  44  RAD/XRAY                 0 non-null      float64
#  45  RHTC/RHDC                0 non-null      float64
#  46  TB DIAG                  0 non-null      float64
#  47  TB LABS                  0 non-null      float64
#  48  TB TREAT                 0 non-null      float64
#  49  YOUTH                    0 non-null      float64
# dtypes: float64(20), int64(1), object(29)
# memory usage: 4.0+ MB

# %% [markdown]
# Some columns seem to have a significant number of null values.

# %%
df = df.drop(['ANC', 'BEOC', 'BLOOD', 'CAES SEC', 'CEOC', 'EPI', 'GROWM', 'HCT', 'OPD', 
              'OUTREACH', 'PMTCT', 'RAD/XRAY', 'RHTC/RHDC', 'TB DIAG', 'TB LABS', 'TB TREAT',
              'YOUTH'], axis=1)

# %%
# Sum up the null values
df.isnull().sum()
# Out:
# Facility Code                  0
# Facility Name                  0
# Province                       0
# County                         0
# District                       0
# Division                     267
# Type                           0
# Owner                          0
# Location                     495
# Sub Location                 892
# Description of Location     5201
# Constituency                   0
# Nearest Town                 602
# Beds                          87
# Cots                          77
# Official Landline           9138
# Official Fax                9965
# Official Mobile             7590
# Official Email              8648
# Official Address            3458
# Official Alternate No       9553
# Town                        2667
# Post Code                   3825
# In Charge                   2140
# Job Title of in Charge      3099
# Open 24 Hours                447
# Open Weekends                457
# Operational Status             0
# ANC                        10505
# ART                         9584
# BEOC                       10505
# BLOOD                      10505
# CAES SEC                   10505
# CEOC                       10505
# C-IMCI                      9328
# EPI                        10505
# FP                          6217
# GROWM                      10505
# HBC                         7707
# HCT                        10505
# IPD                         6562
# OPD                        10505
# OUTREACH                   10505
# PMTCT                      10505
# RAD/XRAY                   10505
# RHTC/RHDC                  10505
# TB DIAG                    10505
# TB LABS                    10505
# TB TREAT                   10505
# YOUTH                      10505
# dtype: int64

# %%
# Drop columns where the sum of null values is exactly 10505 which means they are 0 values.
df = df.drop(columns=[col for col in df.columns if df[col].isnull().sum() == 10505])

# %%
# How many unique values are there?
# Not helpful for my case.
df.nunique()
# Out:
# Facility Code              10505
# Facility Name              10462
# Province                       8
# County                        47
# District                     299
# Division                    1177
# Type                          26
# Owner                         23
# Location                    3487
# Sub Location                5104
# Description of Location     5149
# Constituency                 223
# Nearest Town                3802
# Beds                         161
# Cots                          55
# Official Landline            871
# Official Fax                 207
# Official Mobile             2707
# Official Email              1298
# Official Address            2772
# Official Alternate No        835
# Town                         944
# Post Code                    538
# In Charge                   8099
# Job Title of in Charge         5
# Open 24 Hours                  2
# Open Weekends                  2
# Operational Status             4
# ART                            1
# C-IMCI                         1
# FP                             1
# HBC                            1
# IPD                            1
# dtype: int64

# %% [markdown]
# The 8 provinces, 47 counties indicate that the whole country is well represented.

# %%
# Top 10 facilities with the highest number of beds
df.sort_values(by="Beds", ascending=False).head(10)
# Out:
#       Facility Code                               Facility Name     Province  \
# 2435          13023                  Kenyatta National Hospital      Nairobi
# 1441          13076                            Mathari Hospital      Nairobi
# 5286          12004            Embu Provincial General Hospital      Eastern
# 7315          15288    Nakuru Provincial General Hospital (PGH)  Rift Valley
# 2963          15204              Moi Teaching Refferal Hospital  Rift Valley
# 5511          11289             Coast Province General Hospital        Coast
# 7954          13939    Nyanza Provincial General Hospital (PGH)       Nyanza
# 3826          15915  Kakamega Provincial General Hospital (PGH)      Western
# 2298          13703                    Kisii Hospital (Level 5)       Nyanza
# 1579          12438                   Machakos Level 5 Hospital      Eastern
#
#            County                    District      Division  \
# 2435      Nairobi                       Kibra         Kibra
# 1441      Nairobi                     Mathare      Kariokor
# 5286         Embu                    Manyatta       Central
# 7315       Nakuru                      Nakuru  Municipality
# 2963  Uasin Gishu                Eldoret East      Ainapkoi
# 5511      Mombasa                       Mvita        Island
# 7954       Kisumu                 Kisumu East         Winam
# 3826     Kakamega  Kakamega Central (Lurambi)  Municipality
# 2298        Kisii               Kisii Central  Municipality
# 1579     Machakos                    Machakos       Central
#
#                              Type               Owner         Location  \
# 2435   National Referral Hospital  Ministry of Health       Golfcourse
# 1441            District Hospital  Ministry of Health          Mathare
# 5286  Provincial General Hospital  Ministry of Health     Municipality
# 7315  Provincial General Hospital  Ministry of Health      Nakuru Town
# 2963   National Referral Hospital  Ministry of Health       Chepkoilel
# 5511  Provincial General Hospital  Ministry of Health         Tononoka
# 7954  Provincial General Hospital  Ministry of Health            Kolwa
# 3826  Provincial General Hospital  Ministry of Health         Bukhungu
# 2298            District Hospital  Ministry of Health          Bosongo
# 1579  Provincial General Hospital  Ministry of Health  Masaku Township
#
#      Sub Location  ...                In Charge  Job Title of in Charge  \
# 2435          NaN  ...          Mrs. Lily Koros       Hospital Director
# 1441          NaN  ...  Dr. Nelly Kitazi Okatch  Medical Superintendant
# 5286     Njukiiri  ...       Dr. Gerald Nderitu  Medical Superintendant
# 7315      Viwanda  ...               Dr. Murima  Medical Superintendant
# 2963   Chepkoilel  ...               Dr.Mengich                     NaN
# 5511     Tononoka  ...     Dr. Iqbal Kandwalla         Doctor In Charge
# 7954   Manyatta B  ...        Dr Juliana Otieno                     NaN
# 3826      Shirere  ...      Dr. Daniel Alushula  Medical Superintendant
# 2298      Bosongo  ...          Dr Enock Ondari  Medical Superintendant
# 1579    Eastleigh  ...                Dr. Nzuki  Medical Superintendant
#
#      Open 24 Hours  Open Weekends  Operational Status  ART C-IMCI   FP  HBC  \
# 2435             Y              Y         Operational    Y      Y    Y    Y
# 1441             Y              Y         Operational    Y    NaN  NaN    Y
# 5286             Y              Y         Operational    Y      Y    Y    Y
# 7315             N              N         Operational    Y      Y    Y    Y
# 2963             N              N         Operational    Y      Y    Y    Y
# 5511             Y              Y         Operational    Y      Y    Y    Y
# 7954             Y              Y         Operational    Y      Y    Y    Y
# 3826             Y              Y         Operational  NaN    NaN  NaN  NaN
# 2298             Y              Y         Operational    Y      Y    Y    Y
# 1579             Y              Y         Operational    Y      Y    Y  NaN
#
#       IPD
# 2435    Y
# 1441  NaN
# 5286    Y
# 7315    Y
# 2963    Y
# 5511    Y
# 7954    Y
# 3826  NaN
# 2298    Y
# 1579    Y
#
# [10 rows x 33 columns]

# %%
# Check correlation
# df.corr()

# %%
# heatmap to view the correlations
# sns.heatmap(df.corr(), annot = True)
# plt.rsParams['figure.figsize'] = (20,7)
# plt.show()

# %%
# Group the data
df.groupby('County').mean()
