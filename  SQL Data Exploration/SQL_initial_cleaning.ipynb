# %%
import pandas as pd

df = pd.read_csv('owid-covid-data.csv')

df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-08          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-09          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df['date'] = pd.to_datetime(df['date'])

filtered_df = df.query("date <= '2021-04-30'")

filtered_df.tail()
# Out:
#        iso_code continent  location       date  total_cases  new_cases  \
# 406490      ZWE    Africa  Zimbabwe 2021-04-26      38064.0        0.0
# 406491      ZWE    Africa  Zimbabwe 2021-04-27      38064.0        0.0
# 406492      ZWE    Africa  Zimbabwe 2021-04-28      38064.0        0.0
# 406493      ZWE    Africa  Zimbabwe 2021-04-29      38064.0        0.0
# 406494      ZWE    Africa  Zimbabwe 2021-04-30      38064.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 406490              52.143        1556.0         0.0                0.571
# 406491              52.143        1556.0         0.0                0.571
# 406492              52.143        1556.0         0.0                0.571
# 406493              52.143        1556.0         0.0                0.571
# 406494              52.143        1556.0         0.0                0.571
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
filtered_df.to_csv('covid_data.csv', index=False)
